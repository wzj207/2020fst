# %% [markdown]
# <a href="https://colab.research.google.com/github/wzj207/2020fst/blob/master/%E2%80%9CYOLOv5_Tutorial_gus%E2%80%9D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://user-images.githubusercontent.com/26833433/98702494-b71c4e80-237a-11eb-87ed-17fcd6b3f066.jpg">
#
# This is the **official YOLOv5 🚀 notebook** authored by **Ultralytics**, and is freely available for redistribution under the [GPL-3.0 license](https://choosealicense.com/licenses/gpl-3.0/).
# For more information please visit https://github.com/ultralytics/yolov5 and https://www.ultralytics.com. Thank you!

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.8.1+cu101 (Tesla T4)

# %%
# !unzip -q ../train_data.zip -d ../

# %% [markdown]
# # 1. Inference
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# <img src="https://user-images.githubusercontent.com/26833433/114307955-5c7e4e80-9ae2-11eb-9f50-a90e39bee53f.png" width="900">

# %%
# !python detect.py --weights runs/train/exp5/weights/last.pt --img 640 --conf 0.50 --source ../gus.mp4
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, line_thickness=3, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='../gus.mp4', update=False, view_img=False, weights=['runs/train/exp5/weights/last.pt'])
# YOLOv5 🚀 v5.0-73-gd2a1728 torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPS
# video 1/1 (1/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.010s)
# video 1/1 (2/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.009s)
# video 1/1 (3/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.009s)
# video 1/1 (4/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.009s)
# video 1/1 (5/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.009s)
# video 1/1 (6/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.012s)
# video 1/1 (7/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.009s)
# video 1/1 (8/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.009s)
# video 1/1 (9/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.009s)
# video 1/1 (10/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (11/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (12/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (13/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.009s)
# video 1/1 (14/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (15/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (16/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (17/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (18/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (19/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.011s)
# video 1/1 (20/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (21/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (22/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (23/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (24/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (25/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (26/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (27/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (28/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (29/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (30/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (31/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (32/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (33/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (34/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (35/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (36/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (37/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (38/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (39/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (40/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (41/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (42/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (43/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (44/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (45/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (46/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (47/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (48/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (49/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (50/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (51/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (52/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (53/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (54/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (55/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (56/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (57/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (58/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (59/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.010s)
# video 1/1 (60/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (61/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (62/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (63/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (64/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (65/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (66/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (67/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (68/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (69/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (70/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (71/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (72/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (73/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (74/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (75/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (76/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (77/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (78/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (79/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (80/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (81/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (82/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (83/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (84/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (85/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (86/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (87/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (88/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (89/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (90/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (91/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (92/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (93/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (94/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (95/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (96/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (97/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (98/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (99/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (100/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (101/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (102/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.009s)
# video 1/1 (103/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (104/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.008s)
# video 1/1 (105/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.008s)
# video 1/1 (106/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (107/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (108/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (109/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (110/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (111/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (112/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (113/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (114/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (115/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (116/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (117/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (118/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (119/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (120/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (121/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (122/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (123/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (124/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (125/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (126/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (127/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (128/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (129/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (130/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (131/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.009s)
# video 1/1 (132/450) /content/yolov5/../gus.mp4: 384x640 4 Grus japonensiss, Done. (0.007s)
# video 1/1 (133/450) /content/yolov5/../gus.mp4: 384x640 4 Grus japonensiss, Done. (0.007s)
# video 1/1 (134/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (135/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (136/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (137/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (138/450) /content/yolov5/../gus.mp4: 384x640 4 Grus japonensiss, Done. (0.007s)
# video 1/1 (139/450) /content/yolov5/../gus.mp4: 384x640 4 Grus japonensiss, Done. (0.008s)
# video 1/1 (140/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (141/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (142/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (143/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (144/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (145/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (146/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (147/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (148/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (149/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.011s)
# video 1/1 (150/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.008s)
# video 1/1 (151/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.008s)
# video 1/1 (152/450) /content/yolov5/../gus.mp4: 384x640 4 Grus japonensiss, Done. (0.008s)
# video 1/1 (153/450) /content/yolov5/../gus.mp4: 384x640 4 Grus japonensiss, Done. (0.010s)
# video 1/1 (154/450) /content/yolov5/../gus.mp4: 384x640 4 Grus japonensiss, Done. (0.008s)
# video 1/1 (155/450) /content/yolov5/../gus.mp4: 384x640 4 Grus japonensiss, Done. (0.008s)
# video 1/1 (156/450) /content/yolov5/../gus.mp4: 384x640 4 Grus japonensiss, Done. (0.007s)
# video 1/1 (157/450) /content/yolov5/../gus.mp4: 384x640 4 Grus japonensiss, Done. (0.007s)
# video 1/1 (158/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (159/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (160/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (161/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (162/450) /content/yolov5/../gus.mp4: 384x640 4 Grus japonensiss, Done. (0.007s)
# video 1/1 (163/450) /content/yolov5/../gus.mp4: 384x640 4 Grus japonensiss, Done. (0.007s)
# video 1/1 (164/450) /content/yolov5/../gus.mp4: 384x640 4 Grus japonensiss, Done. (0.007s)
# video 1/1 (165/450) /content/yolov5/../gus.mp4: 384x640 4 Grus japonensiss, Done. (0.007s)
# video 1/1 (166/450) /content/yolov5/../gus.mp4: 384x640 4 Grus japonensiss, Done. (0.007s)
# video 1/1 (167/450) /content/yolov5/../gus.mp4: 384x640 4 Grus japonensiss, Done. (0.007s)
# video 1/1 (168/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (169/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (170/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (171/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (172/450) /content/yolov5/../gus.mp4: 384x640 4 Grus japonensiss, Done. (0.007s)
# video 1/1 (173/450) /content/yolov5/../gus.mp4: 384x640 4 Grus japonensiss, Done. (0.007s)
# video 1/1 (174/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.009s)
# video 1/1 (175/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.008s)
# video 1/1 (176/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (177/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (178/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.008s)
# video 1/1 (179/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (180/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (181/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (182/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (183/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (184/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (185/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (186/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (187/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (188/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (189/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (190/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (191/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (192/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (193/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (194/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (195/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.009s)
# video 1/1 (196/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (197/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.010s)
# video 1/1 (198/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (199/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (200/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (201/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (202/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.010s)
# video 1/1 (203/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (204/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (205/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (206/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (207/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (208/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (209/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (210/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (211/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (212/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (213/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (214/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (215/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (216/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (217/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (218/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.010s)
# video 1/1 (219/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (220/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (221/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (222/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (223/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (224/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (225/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (226/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (227/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.008s)
# video 1/1 (228/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (229/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (230/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.008s)
# video 1/1 (231/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (232/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (233/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.008s)
# video 1/1 (234/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (235/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (236/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (237/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (238/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (239/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (240/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.008s)
# video 1/1 (241/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (242/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (243/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.008s)
# video 1/1 (244/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (245/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (246/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.009s)
# video 1/1 (247/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (248/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (249/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (250/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (251/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (252/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (253/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (254/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.008s)
# video 1/1 (255/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (256/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (257/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (258/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (259/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (260/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (261/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (262/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (263/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (264/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (265/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (266/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (267/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.009s)
# video 1/1 (268/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (269/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (270/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (271/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (272/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (273/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (274/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (275/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.009s)
# video 1/1 (276/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (277/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.009s)
# video 1/1 (278/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (279/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (280/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (281/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (282/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (283/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (284/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (285/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (286/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (287/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (288/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (289/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (290/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (291/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (292/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (293/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (294/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (295/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (296/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (297/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (298/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (299/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.010s)
# video 1/1 (300/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (301/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (302/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (303/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (304/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (305/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (306/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (307/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (308/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (309/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (310/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (311/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (312/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (313/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (314/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (315/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (316/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (317/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (318/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (319/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (320/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (321/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.011s)
# video 1/1 (322/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (323/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (324/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (325/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (326/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (327/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (328/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (329/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (330/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (331/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (332/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (333/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (334/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (335/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (336/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (337/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (338/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (339/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (340/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.009s)
# video 1/1 (341/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (342/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (343/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.010s)
# video 1/1 (344/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (345/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (346/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (347/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (348/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (349/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.009s)
# video 1/1 (350/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (351/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (352/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (353/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (354/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (355/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (356/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (357/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (358/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (359/450) /content/yolov5/../gus.mp4: 384x640 3 Grus japonensiss, Done. (0.007s)
# video 1/1 (360/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (361/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (362/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (363/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (364/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (365/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.009s)
# video 1/1 (366/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (367/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (368/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (369/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (370/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (371/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (372/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (373/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (374/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (375/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (376/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (377/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (378/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (379/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (380/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (381/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (382/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (383/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (384/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (385/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (386/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.011s)
# video 1/1 (387/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.010s)
# video 1/1 (388/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (389/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.008s)
# video 1/1 (390/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (391/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (392/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (393/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (394/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (395/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (396/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (397/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (398/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (399/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (400/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (401/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (402/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (403/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (404/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (405/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (406/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (407/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (408/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (409/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (410/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.008s)
# video 1/1 (411/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.007s)
# video 1/1 (412/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (413/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (414/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (415/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (416/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (417/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (418/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (419/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (420/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (421/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (422/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (423/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (424/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (425/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.009s)
# video 1/1 (426/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (427/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (428/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (429/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (430/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (431/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (432/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.007s)
# video 1/1 (433/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.011s)
# video 1/1 (434/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (435/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (436/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (437/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (438/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (439/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.011s)
# video 1/1 (440/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (441/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (442/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (443/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.009s)
# video 1/1 (444/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.008s)
# video 1/1 (445/450) /content/yolov5/../gus.mp4: 384x640 1 Grus japonensis, Done. (0.009s)
# video 1/1 (446/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.009s)
# video 1/1 (447/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.008s)
# video 1/1 (448/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.008s)
# video 1/1 (449/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.009s)
# video 1/1 (450/450) /content/yolov5/../gus.mp4: 384x640 2 Grus japonensiss, Done. (0.009s)
# Results saved to runs/detect/exp3
# Done. (6.311s)

# %% [markdown]
# # 2. Test
# Test a model's accuracy on [COCO](https://cocodataset.org/#home) val or test-dev datasets. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag. Note that `pycocotools` metrics may be ~1% better than the equivalent repo metrics, as is visible below, due to slight differences in mAP computation.

# %% [markdown]
# ## COCO val2017
# Download [COCO val 2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L14) dataset (1GB - 5000 images), and test model accuracy.

# %%
# Download COCO val2017
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco2017val.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../ && rm tmp.zip

# %%
# Run YOLOv5x on COCO val2017
# !python test.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65

# %% [markdown]
# ## COCO test-dev2017
# Download [COCO test2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L15) dataset (7GB - 40,000 images), to test model accuracy on test-dev set (**20,000 images, no labels**). Results are saved to a `*.json` file which should be **zipped** and submitted to the evaluation server at https://competitions.codalab.org/competitions/20794.

# %%
# Download COCO test-dev2017
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco2017labels.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../ && rm tmp.zip # unzip labels
# !f="test2017.zip" && curl http://images.cocodataset.org/zips/$f -o $f && unzip -q $f && rm $f  # 7GB,  41k images
# %mv ./test2017 ../coco/images  # move to /coco

# %%
# Run YOLOv5s on COCO test-dev2017 using --task test
# !python test.py --weights yolov5s.pt --data coco.yaml --task test

# %% [markdown]
# # 3. Train
#
# Download [COCO128](https://www.kaggle.com/ultralytics/coco128), a small 128-image tutorial dataset, start tensorboard and train YOLOv5s from a pretrained checkpoint for 3 epochs (note actual training is typically much longer, around **300-1000 epochs**, depending on your dataset).

# %%
# Download COCO128
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco128.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../ && rm tmp.zip

# %% [markdown]
# Train a YOLOv5s model on [COCO128](https://www.kaggle.com/ultralytics/coco128) with `--data coco128.yaml`, starting from pretrained `--weights yolov5s.pt`, or from randomly initialized `--weights '' --cfg yolov5s.yaml`. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and **COCO, COCO128, and VOC datasets are downloaded automatically** on first use.
#
# All training results are saved to `runs/train/` with incrementing run directories, i.e. `runs/train/exp2`, `runs/train/exp3` etc.

# %%
# Tensorboard  (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
# Weights & Biases  (optional)
# %pip install -q wandb
import wandb
wandb.login()

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 100 --data custom_data.yaml --weights yolov5s.pt --nosave --cache
# Out:
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v5.0-73-gd2a1728 torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=True, cfg='', data='./data/custom_data.yaml', device='', entity=None, epochs=100, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='exp', noautoanchor=False, nosave=True, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/exp5', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='yolov5s.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# 2021-05-08 10:11:56.680793: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0
# wandb: Install Weights & Biases for YOLOv5 logging with 'pip install wandb' (recommended)
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    156928  models.common.C3                        [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 283 layers, 7063542 parameters, 7063542 gradients, 16.4 GFLOPS
#
# Transferred 356/362 items from yolov5s.pt
# Scaled weight_decay = 0.0005
# Optimizer groups: 62 .bias, 62 conv.weight, 59 other
# train: Scanning '../train_data/labels/train.cache' images and labels... 32 found, 0 missing, 0 empty, 0 corrupted: 100% 32/32 [00:00<00:00, 293051.81it/s]
# train: Caching images (0.0GB): 100% 32/32 [00:00<00:00, 132.79it/s]
# val: Scanning '../train_data/labels/val.cache' images and labels... 7 found, 0 missing, 0 empty, 0 corrupted: 100% 7/7 [00:00<00:00, 42924.16it/s]
# val: Caching images (0.0GB): 100% 7/7 [00:00<00:00, 64.90it/s]
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 4.54, Best Possible Recall (BPR) = 1.0000
# Image sizes 640 train, 640 test
# Using 2 dataloader workers
# Logging results to runs/train/exp5
# Starting training for 100 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       0/99     2.94G    0.1129   0.04121         0    0.1541        86       640: 100% 2/2 [00:03<00:00,  1.64s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.01it/s]
#                  all           7          10     0.00245         0.1    0.000548    0.000125
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       1/99     3.16G     0.115   0.04637         0    0.1613        86       640: 100% 2/2 [00:00<00:00,  3.77it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.42it/s]
#                  all           7          10     0.00259         0.1     0.00057    0.000124
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       2/99     3.16G    0.1096   0.04203         0    0.1516        71       640: 100% 2/2 [00:00<00:00,  4.55it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.81it/s]
#                  all           7          10     0.00283         0.1    0.000595    9.12e-05
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       3/99     3.16G    0.1113   0.04442         0    0.1557        80       640: 100% 2/2 [00:00<00:00,  4.38it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.80it/s]
#                  all           7          10     0.00297         0.1    0.000625    9.48e-05
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       4/99     3.16G    0.1089   0.05234         0    0.1613       126       640: 100% 2/2 [00:00<00:00,  4.26it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.99it/s]
#                  all           7          10     0.00304         0.1    0.000783    0.000102
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       5/99     3.16G    0.1092   0.04309         0    0.1523        97       640: 100% 2/2 [00:00<00:00,  4.11it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.13it/s]
#                  all           7          10     0.00297         0.4     0.00127    0.000206
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       6/99     3.16G    0.1085   0.04757         0    0.1561       115       640: 100% 2/2 [00:00<00:00,  4.08it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.28it/s]
#                  all           7          10     0.00375         0.6     0.00234    0.000404
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       7/99     3.16G     0.105    0.0388         0    0.1438        67       640: 100% 2/2 [00:00<00:00,  4.26it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.98it/s]
#                  all           7          10     0.00369         0.7     0.00279    0.000442
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       8/99     3.16G    0.1032   0.05059         0    0.1538        80       640: 100% 2/2 [00:00<00:00,  4.36it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.53it/s]
#                  all           7          10     0.00366         0.2     0.00167    0.000275
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       9/99     3.16G    0.1027   0.04838         0    0.1511        94       640: 100% 2/2 [00:00<00:00,  4.33it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.17it/s]
#                  all           7          10     0.00354         0.2     0.00167    0.000273
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      10/99     3.16G    0.1019    0.0559         0    0.1578       107       640: 100% 2/2 [00:00<00:00,  4.25it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.08it/s]
#                  all           7          10     0.00502         0.2     0.00221    0.000303
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      11/99     3.16G    0.1001    0.0554         0    0.1555        85       640: 100% 2/2 [00:00<00:00,  4.25it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.68it/s]
#                  all           7          10     0.00538         0.2     0.00229    0.000381
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      12/99     3.16G    0.1017   0.05603         0    0.1578       127       640: 100% 2/2 [00:00<00:00,  4.30it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.66it/s]
#                  all           7          10     0.00554         0.4     0.00338    0.000503
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      13/99     3.16G       0.1   0.04937         0    0.1494       102       640: 100% 2/2 [00:00<00:00,  4.31it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.99it/s]
#                  all           7          10     0.00604         0.4     0.00364    0.000677
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      14/99     3.16G   0.09659   0.04954         0    0.1461        79       640: 100% 2/2 [00:00<00:00,  4.37it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.38it/s]
#                  all           7          10     0.00655         0.4      0.0041    0.000755
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      15/99     3.16G   0.09502   0.05479         0    0.1498        92       640: 100% 2/2 [00:00<00:00,  4.29it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.54it/s]
#                  all           7          10       0.237         0.1      0.0298      0.0035
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      16/99     3.16G   0.09729   0.05876         0    0.1561       112       640: 100% 2/2 [00:00<00:00,  4.13it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.57it/s]
#                  all           7          10        0.32         0.1      0.0407     0.00464
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      17/99     3.16G   0.09375   0.05573         0    0.1495        89       640: 100% 2/2 [00:00<00:00,  4.26it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.82it/s]
#                  all           7          10       0.314         0.1      0.0425     0.00821
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      18/99     3.16G   0.09285   0.06009         0    0.1529       138       640: 100% 2/2 [00:00<00:00,  4.16it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.06it/s]
#                  all           7          10       0.323         0.1      0.0435     0.00851
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      19/99     3.16G   0.09492   0.05181         0    0.1467        85       640: 100% 2/2 [00:00<00:00,  4.32it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.36it/s]
#                  all           7          10       0.331         0.1      0.0466     0.00868
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      20/99     3.16G    0.0946   0.07218         0    0.1668       140       640: 100% 2/2 [00:00<00:00,  4.30it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.99it/s]
#                  all           7          10        0.33         0.1      0.0553      0.0129
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      21/99     3.16G   0.09357   0.05236         0    0.1459       110       640: 100% 2/2 [00:00<00:00,  4.31it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.41it/s]
#                  all           7          10       0.169         0.2      0.0656      0.0128
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      22/99     3.16G   0.08908   0.05095         0      0.14       102       640: 100% 2/2 [00:00<00:00,  4.46it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.98it/s]
#                  all           7          10       0.244         0.2      0.0737      0.0218
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      23/99     3.16G   0.08826   0.05044         0    0.1387        91       640: 100% 2/2 [00:00<00:00,  4.34it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.65it/s]
#                  all           7          10       0.329         0.2       0.101      0.0373
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      24/99     3.16G   0.08952   0.05588         0    0.1454       101       640: 100% 2/2 [00:00<00:00,  4.29it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.81it/s]
#                  all           7          10       0.379         0.4       0.241      0.0322
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      25/99     3.16G   0.08452   0.05739         0    0.1419        99       640: 100% 2/2 [00:00<00:00,  4.31it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.42it/s]
#                  all           7          10       0.361         0.4       0.249      0.0326
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      26/99     3.16G   0.08551   0.05766         0    0.1432        97       640: 100% 2/2 [00:00<00:00,  4.46it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.34it/s]
#                  all           7          10        0.43         0.4       0.333      0.0649
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      27/99     3.16G   0.08039   0.05355         0    0.1339        79       640: 100% 2/2 [00:00<00:00,  4.47it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.99it/s]
#                  all           7          10       0.496       0.394       0.349      0.0855
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      28/99     3.16G   0.08552   0.06349         0     0.149       105       640: 100% 2/2 [00:00<00:00,  4.23it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.42it/s]
#                  all           7          10        0.38         0.4        0.34      0.0847
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      29/99     3.16G   0.08235   0.06597         0    0.1483       109       640: 100% 2/2 [00:00<00:00,  4.23it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.32it/s]
#                  all           7          10       0.324       0.385       0.341       0.085
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      30/99     3.16G    0.0836   0.06605         0    0.1496       109       640: 100% 2/2 [00:00<00:00,  4.38it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.62it/s]
#                  all           7          10       0.496       0.296       0.294      0.0819
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      31/99     3.16G   0.07996   0.05374         0    0.1337        75       640: 100% 2/2 [00:00<00:00,  4.12it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.06it/s]
#                  all           7          10       0.483         0.3       0.321       0.103
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      32/99     3.16G   0.07651   0.06131         0    0.1378        98       640: 100% 2/2 [00:00<00:00,  4.17it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.71it/s]
#                  all           7          10       0.485         0.3       0.346       0.105
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      33/99     3.16G   0.07831   0.06344         0    0.1417        91       640: 100% 2/2 [00:00<00:00,  4.44it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.00it/s]
#                  all           7          10       0.595       0.295        0.37       0.128
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      34/99     3.16G   0.07865   0.06882         0    0.1475       118       640: 100% 2/2 [00:00<00:00,  4.29it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.01it/s]
#                  all           7          10       0.718         0.3       0.394       0.141
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      35/99     3.16G    0.0731   0.06258         0    0.1357       105       640: 100% 2/2 [00:00<00:00,  4.30it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.56it/s]
#                  all           7          10       0.377         0.5       0.418       0.145
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      36/99     3.16G   0.07652   0.05688         0    0.1334       100       640: 100% 2/2 [00:00<00:00,  4.20it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.54it/s]
#                  all           7          10       0.414       0.496       0.429       0.175
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      37/99     3.16G   0.07301   0.06355         0    0.1366       113       640: 100% 2/2 [00:00<00:00,  4.26it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.56it/s]
#                  all           7          10        0.77         0.4       0.483       0.182
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      38/99     3.16G   0.07572   0.06468         0    0.1404       116       640: 100% 2/2 [00:00<00:00,  4.36it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.42it/s]
#                  all           7          10       0.969         0.4       0.507       0.186
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      39/99     3.16G   0.07636   0.05168         0     0.128        86       640: 100% 2/2 [00:00<00:00,  4.35it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.88it/s]
#                  all           7          10       0.977         0.4       0.534       0.186
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      40/99     3.16G   0.07037   0.05292         0    0.1233        86       640: 100% 2/2 [00:00<00:00,  4.15it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.58it/s]
#                  all           7          10       0.826         0.5       0.603       0.218
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      41/99     3.16G   0.07596   0.06605         0     0.142        91       640: 100% 2/2 [00:00<00:00,  4.12it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.31it/s]
#                  all           7          10       0.805         0.5       0.596       0.203
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      42/99     3.16G    0.0719    0.0709         0    0.1428       113       640: 100% 2/2 [00:00<00:00,  4.35it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.86it/s]
#                  all           7          10       0.817         0.5       0.558       0.175
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      43/99     3.16G   0.06945   0.06676         0    0.1362        99       640: 100% 2/2 [00:00<00:00,  4.30it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.83it/s]
#                  all           7          10        0.83         0.5       0.559       0.171
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      44/99     3.16G   0.06866   0.05902         0    0.1277        97       640: 100% 2/2 [00:00<00:00,  4.29it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.88it/s]
#                  all           7          10       0.828         0.5       0.562       0.178
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      45/99     3.16G   0.06737   0.05663         0     0.124       104       640: 100% 2/2 [00:00<00:00,  4.38it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.02it/s]
#                  all           7          10       0.833       0.499       0.594        0.19
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      46/99     3.16G   0.06942   0.05583         0    0.1252       106       640: 100% 2/2 [00:00<00:00,  4.32it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.22it/s]
#                  all           7          10       0.833         0.5       0.583       0.218
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      47/99     3.16G    0.0695   0.06306         0    0.1326        84       640: 100% 2/2 [00:00<00:00,  4.30it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.86it/s]
#                  all           7          10       0.831         0.5        0.61       0.247
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      48/99     3.16G   0.06666   0.05455         0    0.1212        98       640: 100% 2/2 [00:00<00:00,  4.44it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.31it/s]
#                  all           7          10       0.659         0.6        0.63       0.222
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      49/99     3.16G   0.06655    0.0683         0    0.1348       132       640: 100% 2/2 [00:00<00:00,  4.36it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.68it/s]
#                  all           7          10       0.699       0.696       0.653       0.262
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      50/99     3.16G   0.06384   0.05806         0    0.1219       116       640: 100% 2/2 [00:00<00:00,  4.34it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.63it/s]
#                  all           7          10       0.749       0.598       0.633       0.215
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      51/99     3.16G   0.06738   0.06294         0    0.1303       131       640: 100% 2/2 [00:00<00:00,  4.22it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.42it/s]
#                  all           7          10       0.749         0.6       0.638       0.216
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      52/99     3.16G   0.06404   0.06131         0    0.1253       106       640: 100% 2/2 [00:00<00:00,  4.37it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.30it/s]
#                  all           7          10       0.854         0.6       0.664       0.227
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      53/99     3.16G   0.06291   0.05046         0    0.1134       110       640: 100% 2/2 [00:00<00:00,  4.23it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.68it/s]
#                  all           7          10       0.855         0.6       0.699       0.273
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      54/99     3.16G   0.06272   0.05086         0    0.1136        94       640: 100% 2/2 [00:00<00:00,  4.38it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.66it/s]
#                  all           7          10       0.855         0.6       0.702       0.276
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      55/99     3.16G   0.06287   0.04883         0    0.1117        85       640: 100% 2/2 [00:00<00:00,  4.21it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.14it/s]
#                  all           7          10       0.857         0.6       0.715       0.265
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      56/99     3.16G    0.0611   0.04773         0    0.1088        85       640: 100% 2/2 [00:00<00:00,  4.28it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.08it/s]
#                  all           7          10       0.856         0.6       0.729        0.27
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      57/99     3.16G   0.06069   0.05439         0    0.1151       102       640: 100% 2/2 [00:00<00:00,  4.40it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.16it/s]
#                  all           7          10           1         0.6       0.793        0.35
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      58/99     3.16G   0.06153    0.0477         0    0.1092        93       640: 100% 2/2 [00:00<00:00,  4.26it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.75it/s]
#                  all           7          10       0.875       0.698       0.813       0.358
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      59/99     3.16G   0.06477   0.06867         0    0.1334       151       640: 100% 2/2 [00:00<00:00,  4.19it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.64it/s]
#                  all           7          10       0.998         0.6       0.784       0.319
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      60/99     3.16G   0.06025     0.046         0    0.1062       105       640: 100% 2/2 [00:00<00:00,  4.11it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  8.75it/s]
#                  all           7          10       0.999         0.6        0.81       0.351
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      61/99     3.16G   0.06356    0.0639         0    0.1275       128       640: 100% 2/2 [00:00<00:00,  4.16it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.43it/s]
#                  all           7          10           1         0.6       0.804       0.372
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      62/99     3.16G   0.05935   0.05859         0    0.1179       106       640: 100% 2/2 [00:00<00:00,  4.20it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.31it/s]
#                  all           7          10         0.8       0.799       0.837       0.403
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      63/99     3.16G   0.05983   0.05927         0    0.1191       112       640: 100% 2/2 [00:00<00:00,  4.45it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.23it/s]
#                  all           7          10       0.727         0.8       0.819       0.388
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      64/99     3.16G   0.05869   0.04237         0    0.1011        83       640: 100% 2/2 [00:00<00:00,  4.36it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.84it/s]
#                  all           7          10       0.724         0.8        0.83       0.397
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      65/99     3.16G   0.05623   0.04931         0    0.1055       113       640: 100% 2/2 [00:00<00:00,  4.17it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.31it/s]
#                  all           7          10           1         0.6        0.83       0.384
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      66/99     3.16G   0.05842   0.04918         0    0.1076       100       640: 100% 2/2 [00:00<00:00,  4.34it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.21it/s]
#                  all           7          10       0.725         0.8       0.842       0.404
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      67/99     3.16G   0.05518   0.04543         0    0.1006        99       640: 100% 2/2 [00:00<00:00,  4.17it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.82it/s]
#                  all           7          10       0.799       0.798       0.872       0.428
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      68/99     3.16G   0.05692    0.0385         0   0.09542        64       640: 100% 2/2 [00:00<00:00,  4.31it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.11it/s]
#                  all           7          10         0.8       0.799       0.868       0.413
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      69/99     3.16G    0.0529   0.04061         0   0.09351        80       640: 100% 2/2 [00:00<00:00,  4.46it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.36it/s]
#                  all           7          10         0.8         0.8        0.88       0.414
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      70/99     3.16G   0.05491   0.04625         0    0.1012        81       640: 100% 2/2 [00:00<00:00,  4.36it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.65it/s]
#                  all           7          10        0.75       0.899       0.896       0.428
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      71/99     3.16G   0.05475   0.04697         0    0.1017        79       640: 100% 2/2 [00:00<00:00,  4.44it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.42it/s]
#                  all           7          10       0.818       0.899       0.909       0.438
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      72/99     3.16G   0.05488   0.04669         0    0.1016       116       640: 100% 2/2 [00:00<00:00,  4.41it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.82it/s]
#                  all           7          10         0.8         0.8       0.894       0.439
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      73/99     3.16G   0.05636   0.04612         0    0.1025       107       640: 100% 2/2 [00:00<00:00,  4.32it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.60it/s]
#                  all           7          10       0.833       0.998       0.933        0.45
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      74/99     3.16G   0.06018   0.04954         0    0.1097        77       640: 100% 2/2 [00:00<00:00,  4.24it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.93it/s]
#                  all           7          10       0.833       0.999       0.933       0.483
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      75/99     3.16G   0.05526    0.0441         0   0.09936        76       640: 100% 2/2 [00:00<00:00,  4.19it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.76it/s]
#                  all           7          10       0.833       0.999       0.945       0.505
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      76/99     3.16G    0.0565    0.0483         0    0.1048       103       640: 100% 2/2 [00:00<00:00,  4.32it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.77it/s]
#                  all           7          10           1         0.9       0.978        0.59
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      77/99     3.16G   0.05198   0.05206         0     0.104       100       640: 100% 2/2 [00:00<00:00,  4.33it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.94it/s]
#                  all           7          10           1         0.9       0.978       0.605
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      78/99     3.16G   0.05511   0.04559         0    0.1007       107       640: 100% 2/2 [00:00<00:00,  4.25it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.62it/s]
#                  all           7          10         0.9         0.9       0.952       0.545
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      79/99     3.16G   0.05571   0.04942         0    0.1051       112       640: 100% 2/2 [00:00<00:00,  4.12it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 13.04it/s]
#                  all           7          10       0.999         0.9       0.978       0.582
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      80/99     3.16G    0.0515   0.05043         0    0.1019        95       640: 100% 2/2 [00:00<00:00,  4.21it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.44it/s]
#                  all           7          10           1       0.899       0.978       0.529
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      81/99     3.16G   0.05565   0.04825         0    0.1039       123       640: 100% 2/2 [00:00<00:00,  4.17it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 11.44it/s]
#                  all           7          10       0.833       0.998       0.958       0.501
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      82/99     3.16G   0.05393   0.04897         0    0.1029       107       640: 100% 2/2 [00:00<00:00,  4.21it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.83it/s]
#                  all           7          10       0.999         0.9       0.986       0.515
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      83/99     3.16G   0.05265   0.04206         0   0.09471        77       640: 100% 2/2 [00:00<00:00,  4.56it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.55it/s]
#                  all           7          10         0.9           1       0.986       0.548
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      84/99     3.16G   0.05176   0.04455         0   0.09631        75       640: 100% 2/2 [00:00<00:00,  4.59it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.07it/s]
#                  all           7          10           1         0.9       0.986       0.593
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      85/99     3.16G     0.053   0.04522         0   0.09822       114       640: 100% 2/2 [00:00<00:00,  4.62it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.19it/s]
#                  all           7          10           1       0.899       0.978        0.56
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      86/99     3.16G   0.05237   0.04642         0   0.09879       117       640: 100% 2/2 [00:00<00:00,  4.55it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.00it/s]
#                  all           7          10           1       0.899       0.978       0.569
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      87/99     3.16G   0.05157   0.04131         0   0.09288        90       640: 100% 2/2 [00:00<00:00,  4.62it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.47it/s]
#                  all           7          10       0.908           1       0.986       0.595
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      88/99     3.16G   0.05449   0.05073         0    0.1052       120       640: 100% 2/2 [00:00<00:00,  4.64it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.44it/s]
#                  all           7          10       0.909       0.997       0.986       0.577
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      89/99     3.16G   0.05326   0.04329         0   0.09655       115       640: 100% 2/2 [00:00<00:00,  4.63it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.06it/s]
#                  all           7          10       0.999         0.9       0.978       0.605
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      90/99     3.16G   0.05314   0.04876         0    0.1019       128       640: 100% 2/2 [00:00<00:00,  4.64it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.60it/s]
#                  all           7          10       0.906           1       0.986       0.584
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      91/99     3.16G   0.05069   0.04251         0   0.09321       105       640: 100% 2/2 [00:00<00:00,  4.51it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.62it/s]
#                  all           7          10       0.908           1       0.986       0.584
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      92/99     3.16G   0.05043   0.04284         0   0.09327        91       640: 100% 2/2 [00:00<00:00,  4.67it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.32it/s]
#                  all           7          10       0.907           1       0.986       0.587
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      93/99     3.16G   0.05482   0.04261         0   0.09743        85       640: 100% 2/2 [00:00<00:00,  4.54it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.73it/s]
#                  all           7          10       0.908           1       0.986       0.567
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      94/99     3.16G   0.05234   0.04912         0    0.1015        85       640: 100% 2/2 [00:00<00:00,  4.65it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.64it/s]
#                  all           7          10       0.909       0.999       0.986       0.592
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      95/99     3.16G   0.05091   0.04273         0   0.09364       101       640: 100% 2/2 [00:00<00:00,  4.50it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.03it/s]
#                  all           7          10       0.909       0.998       0.986       0.586
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      96/99     3.16G   0.05108    0.0421         0   0.09318        95       640: 100% 2/2 [00:00<00:00,  4.70it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00, 10.83it/s]
#                  all           7          10       0.907           1       0.986       0.569
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      97/99     3.16G   0.04997   0.03487         0   0.08484        73       640: 100% 2/2 [00:00<00:00,  4.73it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.72it/s]
#                  all           7          10       0.909           1       0.986       0.586
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      98/99     3.16G   0.05433   0.04806         0    0.1024       110       640: 100% 2/2 [00:00<00:00,  4.55it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  9.38it/s]
#                  all           7          10       0.908           1       0.986       0.621
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      99/99     3.16G   0.04709   0.04168         0   0.08877       104       640: 100% 2/2 [00:00<00:00,  4.71it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.59it/s]
#                  all           7          10       0.909       0.996       0.986       0.604
# 100 epochs completed in 0.019 hours.
#
# Optimizer stripped from runs/train/exp5/weights/last.pt, 14.4MB

# %% [markdown]
# # 4. Visualize

# %% [markdown]
# ## Weights & Biases Logging 🌟 NEW
#
# [Weights & Biases](https://wandb.ai/site?utm_campaign=repo_yolo_notebook) (W&B) is now integrated with YOLOv5 for real-time visualization and cloud logging of training runs. This allows for better run comparison and introspection, as well improved visibility and collaboration for teams. To enable W&B `pip install wandb`, and then train normally (you will be guided through setup on first use).
#
# During training you will see live updates at [https://wandb.ai/home](https://wandb.ai/home?utm_campaign=repo_yolo_notebook), and you can create and share detailed [Reports](https://wandb.ai/glenn-jocher/yolov5_tutorial/reports/YOLOv5-COCO128-Tutorial-Results--VmlldzozMDI5OTY) of your results. For more information see the [YOLOv5 Weights & Biases Tutorial](https://github.com/ultralytics/yolov5/issues/1289).
#
# <img src="https://user-images.githubusercontent.com/26833433/98184457-bd3da580-1f0a-11eb-8461-95d908a71893.jpg" width="800">

# %% [markdown]
# ## Local Logging
#
# All results are logged by default to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc. View train and test jpgs to see mosaics, labels, predictions and augmentation effects. Note a **Mosaic Dataloader** is used for training (shown below), a new concept developed by Ultralytics and first featured in [YOLOv4](https://arxiv.org/abs/2004.10934).

# %%
Image(filename='runs/train/exp/train_batch0.jpg', width=800)  # train batch 0 mosaics and labels
Image(filename='runs/train/exp/test_batch0_labels.jpg', width=800)  # test batch 0 labels
Image(filename='runs/train/exp/test_batch0_pred.jpg', width=800)  # test batch 0 predictions

# %% [markdown]
# > <img src="https://user-images.githubusercontent.com/26833433/83667642-90fcb200-a583-11ea-8fa3-338bbf7da194.jpeg" width="750">
# `train_batch0.jpg` shows train batch 0 mosaics and labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/83667626-8c37fe00-a583-11ea-997b-0923fe59b29b.jpeg" width="750">
# `test_batch0_labels.jpg` shows test batch 0 labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/83667635-90641b80-a583-11ea-8075-606316cebb9c.jpeg" width="750">
# `test_batch0_pred.jpg` shows test batch 0 _predictions_

# %% [markdown]
# Training losses and performance metrics are also logged to [Tensorboard](https://www.tensorflow.org/tensorboard) and a custom `results.txt` logfile which is plotted as `results.png` (below) after training completes. Here we show YOLOv5s trained on COCO128 to 300 epochs, starting from scratch (blue), and from pretrained `--weights yolov5s.pt` (orange).

# %%
from utils.plots import plot_results 
plot_results(save_dir='runs/train/exp')  # plot all results*.txt as results.png
Image(filename='runs/train/exp/results.png', width=800)

# %% [markdown]
# <img src="https://user-images.githubusercontent.com/26833433/97808309-8182b180-1c66-11eb-8461-bffe1a79511d.png" width="800">

# %% [markdown]
# # Environments
#
# YOLOv5 may be run in any of the following up-to-date verified environments (with all dependencies including [CUDA](https://developer.nvidia.com/cuda)/[CUDNN](https://developer.nvidia.com/cudnn), [Python](https://www.python.org/) and [PyTorch](https://pytorch.org/) preinstalled):
#
# - **Google Colab and Kaggle** notebooks with free GPU: <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a> <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# - **Google Cloud** Deep Learning VM. See [GCP Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/GCP-Quickstart)
# - **Amazon** Deep Learning AMI. See [AWS Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/AWS-Quickstart)
# - **Docker Image**. See [Docker Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/Docker-Quickstart) <a href="https://hub.docker.com/r/ultralytics/yolov5"><img src="https://img.shields.io/docker/pulls/ultralytics/yolov5?logo=docker" alt="Docker Pulls"></a>

# %% [markdown]
# # Status
#
# ![CI CPU testing](https://github.com/ultralytics/yolov5/workflows/CI%20CPU%20testing/badge.svg)
#
# If this badge is green, all [YOLOv5 GitHub Actions](https://github.com/ultralytics/yolov5/actions) Continuous Integration (CI) tests are currently passing. CI tests verify correct operation of YOLOv5 training ([train.py](https://github.com/ultralytics/yolov5/blob/master/train.py)), testing ([test.py](https://github.com/ultralytics/yolov5/blob/master/test.py)), inference ([detect.py](https://github.com/ultralytics/yolov5/blob/master/detect.py)) and export ([export.py](https://github.com/ultralytics/yolov5/blob/master/models/export.py)) on MacOS, Windows, and Ubuntu every 24 hours and on every commit.

# %% [markdown]
# # Appendix
#
# Optional extras below. Unit tests validate repo functionality and should be run on any PRs submitted.

# %%
# Re-clone repo
# %cd ..
# %rm -rf yolov5 && git clone https://github.com/ultralytics/yolov5
# %cd yolov5

# %%
# Reproduce
for x in 'yolov5s', 'yolov5m', 'yolov5l', 'yolov5x':
  # !python test.py --weights {x}.pt --data coco.yaml --img 640 --conf 0.25 --iou 0.45  # speed
  # !python test.py --weights {x}.pt --data coco.yaml --img 640 --conf 0.001 --iou 0.65  # mAP

# %%
# PyTorch Hub
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Images
dir = 'https://github.com/ultralytics/yolov5/raw/master/data/images/'
imgs = [dir + f for f in ('zidane.jpg', 'bus.jpg')]  # batch of images

# Inference
results = model(imgs)
results.print()  # or .show(), .save()

# %%
# Unit tests
# %%shell
export PYTHONPATH="$PWD"  # to run *.py. files in subdirectories

rm -rf runs  # remove runs/
for m in yolov5s; do  # models
  python train.py --weights $m.pt --epochs 3 --img 320 --device 0  # train pretrained
  python train.py --weights '' --cfg $m.yaml --epochs 3 --img 320 --device 0  # train scratch
  for d in 0 cpu; do  # devices
    python detect.py --weights $m.pt --device $d  # detect official
    python detect.py --weights runs/train/exp/weights/best.pt --device $d  # detect custom
    python test.py --weights $m.pt --device $d # test official
    python test.py --weights runs/train/exp/weights/best.pt --device $d # test custom
  done
  python hubconf.py  # hub
  python models/yolo.py --cfg $m.yaml  # inspect
  python models/export.py --weights $m.pt --img 640 --batch 1  # export
done

# %%
# Profile
from utils.torch_utils import profile 

m1 = lambda x: x * torch.sigmoid(x)
m2 = torch.nn.SiLU()
profile(x=torch.randn(16, 3, 640, 640), ops=[m1, m2], n=100)

# %%
# Evolve
# !python train.py --img 640 --batch 64 --epochs 100 --data coco128.yaml --weights yolov5s.pt --cache --noautoanchor --evolve
# !d=runs/train/evolve && cp evolve.* $d && zip -r evolve.zip $d && gsutil mv evolve.zip gs://bucket  # upload results (optional)

# %%
# VOC
for b, m in zip([64, 48, 32, 16], ['yolov5s', 'yolov5m', 'yolov5l', 'yolov5x']):  # zip(batch_size, model)
  # !python train.py --batch {b} --weights {m}.pt --data voc.yaml --epochs 50 --cache --img 512 --nosave --hyp hyp.finetune.yaml --project VOC --name {m}
